# %% [markdown]
# <a href="https://colab.research.google.com/github/njugunah800/Import-cv2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %%
import pandas as pd
import random

# Define sample data
weather_conditions = ['Clear', 'Rainy', 'Snowy', 'Foggy']
road_types = ['Highway', 'City Street', 'Rural Road']
traffic_volumes = ['Low', 'Medium', 'High']
driver_behaviors = ['Normal', 'Reckless', 'Distracted']

# Generate random sample data
data = {
    'Weather': random.choices(weather_conditions, k=100),
    'Road_Type': random.choices(road_types, k=100),
    'Traffic_Volume': random.choices(traffic_volumes, k=100),
    'Driver_Behavior': random.choices(driver_behaviors, k=100),
    'Accident_Severity': random.choices([1, 2, 3], k=100)  # 1: Minor, 2: Moderate, 3: Severe
}

# Create a DataFrame
df = pd.DataFrame(data)

# Save the dataset to a CSV file
df.to_csv('accident_dataset.csv', index=False)

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('accident_dataset.csv')

# Print the first few rows of the DataFrame to verify the data has been loaded successfully
print(df.head())
# Out:
#   Weather    Road_Type Traffic_Volume Driver_Behavior  Accident_Severity
# 0   Snowy   Rural Road            Low      Distracted                  2
# 1   Rainy      Highway            Low        Reckless                  1
# 2   Rainy  City Street         Medium      Distracted                  1
# 3   Snowy  City Street            Low      Distracted                  2
# 4   Clear   Rural Road            Low          Normal                  1

# %%
# Import necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import joblib

# Assume X represents the independent variables and Y represents the accident severity
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Create and train the linear regression model
# model = LinearRegression()
# model.fit(X_train, Y_train)

# Save the model for future use
# joblib.dump(model, 'accident_severity_model.pkl')

# To load the model later:
# loaded_model = joblib.load('accident_severity_model.pkl')

# Example usage of the model to predict accident severity
# predicted_severity = loaded_model.predict([[weather, road_type, traffic_volume, time_of_day]])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('accident_dataset.csv')

# Data exploration
print(df.head())  # Display the first few rows of the dataset
print(df.info())  # Summary of the dataset, including data types and missing values
print(df.describe())  # Statistical summary of numerical columns
# Out:
#   Weather    Road_Type Traffic_Volume Driver_Behavior  Accident_Severity
# 0   Clear  City Street           High        Reckless                  1
# 1   Clear      Highway            Low        Reckless                  2
# 2   Rainy      Highway            Low      Distracted                  3
# 3   Clear  City Street            Low      Distracted                  1
# 4   Foggy  City Street           High        Reckless                  1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Weather            100 non-null    object
#  1   Road_Type          100 non-null    object
#  2   Traffic_Volume     100 non-null    object
#  3   Driver_Behavior    100 non-null    object
#  4   Accident_Severity  100 non-null    int64
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB
# None
#        Accident_Severity
# ...
